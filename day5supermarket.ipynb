# %%
import pandas as pd
import numpy as np
df=pd.read_csv("C:/Users/user/Documents/supermarket_sales.csv")
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   01-05-19
# 1  Electronic accessories       15.28         5   3.8200   80.2200   03-08-19
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   03-03-19
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   02-08-19
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
df.shape
# Out:
# (1000, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   01-05-19
# 1  Electronic accessories       15.28         5   3.8200   80.2200   03-08-19
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   03-03-19
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   02-08-19
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
import datetime
df['day']=df['Date'].dt.day
df['month']=df['Date'].dt.month
df['year']=df['Date'].dt.year
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2019-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2019-03-08
# 2      Home and lifestyle       46.33         7  16.2155  340.5255 2019-03-03
# 3       Health and beauty       58.22         8  23.2880  489.0480 2019-01-27
# 4       Sports and travel       86.31         7  30.2085  634.3785 2019-02-08
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating  \
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
df['month'][34]
# Out:
# 2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   datetime64[ns]
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
# ...

# %%
df['Time']=pd.to_datetime(df['Time'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   datetime64[ns]
#  11  Time                     1000 non-null   datetime64[ns]
#  12  Payment                  1000 non-null   object
# ...

# %%
df2=df.rename({'Invoice ID': 'Invoice_ID',
  'Customer type':'Customer_Type',
  'Product line':'Product_Line',
  'Unit price':'Unit_Price',
  'gross margin percentage':'Gross_margin_Percentage',
  'gross income':'Gross_Income'}, axis="columns")

# %%
# 1. find the cumulative frequency of gross income, the new column should be called
#  gross-cum_freq
# 2.if the rating is more than 7.5, write good, else write bad, new column
# should be called star_rating

# %%
df2.head()
# Out:
#     Invoice_ID Branch       City Customer_Type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product_Line  Unit_Price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2019-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2019-03-08
# 2      Home and lifestyle       46.33         7  16.2155  340.5255 2019-03-03
# 3       Health and beauty       58.22         8  23.2880  489.0480 2019-01-27
# 4       Sports and travel       86.31         7  30.2085  634.3785 2019-02-08
#
#                  Time      Payment    cogs  Gross_margin_Percentage  \
# 0 2024-01-24 13:08:00      Ewallet  522.83                 4.761905
# ...

# %%
df2['Rating'].unique()
# Out:
# array([ 9.1,  9.6,  7.4,  8.4,  5.3,  4.1,  5.8,  8. ,  7.2,  5.9,  4.5,
#         6.8,  7.1,  8.2,  5.7,  4.6,  6.9,  8.6,  4.4,  4.8,  5.1,  9.9,
#         6. ,  8.5,  6.7,  7.7,  7.5,  7. ,  4.7,  7.6,  7.9,  6.3,  5.6,
#         9.5,  8.1,  6.5,  6.1,  6.6,  5.4,  9.3, 10. ,  6.4,  4.3,  4. ,
#         8.7,  9.4,  5.5,  8.3,  7.3,  4.9,  4.2,  9.2,  7.8,  5.2,  9. ,
#         8.8,  6.2,  9.8,  9.7,  5. ,  8.9])

# %%
df_hb=df2[(df2.Product_Line=='Health and beauty')]
df_hb.head()
# Out:
#      Invoice_ID Branch    City Customer_Type  Gender       Product_Line  \
# 0   750-67-8428      A  Yangon        Member  Female  Health and beauty
# 3   123-19-1176      A  Yangon        Member    Male  Health and beauty
# 8   665-32-9167      A  Yangon        Member  Female  Health and beauty
# 14  829-34-3910      A  Yangon        Normal  Female  Health and beauty
# 16  656-95-9349      A  Yangon        Member  Female  Health and beauty
#
#     Unit_Price  Quantity   Tax 5%     Total       Date                Time  \
# 0        74.69         7  26.1415  548.9715 2019-01-05 2024-01-24 13:08:00
# 3        58.22         8  23.2880  489.0480 2019-01-27 2024-01-24 20:33:00
# 8        36.26         2   3.6260   76.1460 2019-01-10 2024-01-24 17:15:00
# 14       71.38        10  35.6900  749.4900 2019-03-29 2024-01-24 19:21:00
# 16       68.93         7  24.1255  506.6355 2019-03-11 2024-01-24 11:03:00
#
#         Payment    cogs  Gross_margin_Percentage  Gross_Income  Rating  day  \
# ...

# %%
# between male and female, who uses more healthcare products
x=df_male=df_hb[(df_hb.Gender=='Male')]
x.head()
# Out:
#      Invoice_ID Branch       City Customer_Type Gender       Product_Line  \
# 3   123-19-1176      A     Yangon        Member   Male  Health and beauty
# 21  371-85-5789      B   Mandalay        Normal   Male  Health and beauty
# 29  848-62-7243      A     Yangon        Normal   Male  Health and beauty
# 33  595-11-5460      A     Yangon        Normal   Male  Health and beauty
# 44  617-15-4209      C  Naypyitaw        Member   Male  Health and beauty
#
#     Unit_Price  Quantity   Tax 5%     Total       Date                Time  \
# 3        58.22         8  23.2880  489.0480 2019-01-27 2024-01-24 20:33:00
# 21       87.98         3  13.1970  277.1370 2019-03-05 2024-01-24 10:40:00
# 29       24.89         9  11.2005  235.2105 2019-03-15 2024-01-24 15:36:00
# 33       96.58         2   9.6580  202.8180 2019-03-15 2024-01-24 10:12:00
# 44       15.37         2   1.5370   32.2770 2019-03-16 2024-01-24 19:47:00
#
# ...

# %%
x=df_male.groupby('Product_Line')['Quantity'].sum()
x
# Out:
# Product_Line
# Health and beauty    511
# Name: Quantity, dtype: int64

# %%
df_female=df_hb[(df_hb.Gender=='Female')]
df_female.head()
# Out:
#      Invoice_ID Branch       City Customer_Type  Gender       Product_Line  \
# 0   750-67-8428      A     Yangon        Member  Female  Health and beauty
# 8   665-32-9167      A     Yangon        Member  Female  Health and beauty
# 14  829-34-3910      A     Yangon        Normal  Female  Health and beauty
# 16  656-95-9349      A     Yangon        Member  Female  Health and beauty
# 38  333-73-7901      C  Naypyitaw        Normal  Female  Health and beauty
#
#     Unit_Price  Quantity   Tax 5%     Total       Date                Time  \
# 0        74.69         7  26.1415  548.9715 2019-01-05 2024-01-24 13:08:00
# 8        36.26         2   3.6260   76.1460 2019-01-10 2024-01-24 17:15:00
# 14       71.38        10  35.6900  749.4900 2019-03-29 2024-01-24 19:21:00
# 16       68.93         7  24.1255  506.6355 2019-03-11 2024-01-24 11:03:00
# 38       54.92         8  21.9680  461.3280 2019-03-23 2024-01-24 13:24:00
#
# ...

# %%
y=df_female.groupby('Product_Line')['Quantity'].sum()
y
# Out:
# Product_Line
# Health and beauty    343
# Name: Quantity, dtype: int64

# %%
# between male and female who uses more home/lifestyle products
df_home=df2[(df2.Product_Line=='Home and lifestyle')]
df_home.head()
# Out:
#      Invoice_ID Branch       City Customer_Type  Gender        Product_Line  \
# 2   631-41-3108      A     Yangon        Normal    Male  Home and lifestyle
# 7   315-22-5665      C  Naypyitaw        Normal  Female  Home and lifestyle
# 19  319-50-3348      B   Mandalay        Normal  Female  Home and lifestyle
# 22  273-16-6619      B   Mandalay        Normal    Male  Home and lifestyle
# 25  227-03-5010      A     Yangon        Member  Female  Home and lifestyle
#
#     Unit_Price  Quantity   Tax 5%     Total       Date                Time  \
# 2        46.33         7  16.2155  340.5255 2019-03-03 2024-01-24 13:23:00
# 7        73.56        10  36.7800  772.3800 2019-02-24 2024-01-24 11:38:00
# 19       40.30         2   4.0300   84.6300 2019-03-11 2024-01-24 15:30:00
# 22       33.20         2   3.3200   69.7200 2019-03-15 2024-01-24 12:20:00
# 25       52.59         8  21.0360  441.7560 2019-03-22 2024-01-24 19:20:00
#
# ...

# %%
df_male_h=df_home[(df_home.Gender=='Male')]
df_male_h.head()
# Out:
#      Invoice_ID Branch       City Customer_Type Gender        Product_Line  \
# 2   631-41-3108      A     Yangon        Normal   Male  Home and lifestyle
# 22  273-16-6619      B   Mandalay        Normal   Male  Home and lifestyle
# 39  777-82-7220      B   Mandalay        Member   Male  Home and lifestyle
# 41  554-53-8700      C  Naypyitaw        Member   Male  Home and lifestyle
# 54  242-55-6721      B   Mandalay        Normal   Male  Home and lifestyle
#
#     Unit_Price  Quantity   Tax 5%     Total       Date                Time  \
# 2        46.33         7  16.2155  340.5255 2019-03-03 2024-01-24 13:23:00
# 22       33.20         2   3.3200   69.7200 2019-03-15 2024-01-24 12:20:00
# 39       30.12         8  12.0480  253.0080 2019-03-03 2024-01-24 13:01:00
# 41       56.11         2   5.6110  117.8310 2019-02-02 2024-01-24 10:11:00
# 54       16.16         2   1.6160   33.9360 2019-03-07 2024-01-24 11:49:00
#
# ...

# %%
df_male_h.groupby('Product_Line')['Quantity'].sum()
# Out:
# Product_Line
# Home and lifestyle    413
# Name: Quantity, dtype: int64

# %%
df_female_h=df_home[(df_home.Gender=='Female')]
df_female_h.head()
# Out:
#      Invoice_ID Branch       City Customer_Type  Gender        Product_Line  \
# 7   315-22-5665      C  Naypyitaw        Normal  Female  Home and lifestyle
# 19  319-50-3348      B   Mandalay        Normal  Female  Home and lifestyle
# 25  227-03-5010      A     Yangon        Member  Female  Home and lifestyle
# 40  280-35-5823      B   Mandalay        Member  Female  Home and lifestyle
# 58  817-48-8732      A     Yangon        Member  Female  Home and lifestyle
#
#     Unit_Price  Quantity  Tax 5%    Total       Date                Time  \
# 7        73.56        10  36.780  772.380 2019-02-24 2024-01-24 11:38:00
# 19       40.30         2   4.030   84.630 2019-03-11 2024-01-24 15:30:00
# 25       52.59         8  21.036  441.756 2019-03-22 2024-01-24 19:20:00
# 40       86.72         1   4.336   91.056 2019-01-17 2024-01-24 18:45:00
# 58       72.35        10  36.175  759.675 2019-01-20 2024-01-24 15:55:00
#
# ...

# %%
df_female_h.groupby('Product_Line')['Quantity'].sum()
# Out:
# Product_Line
# Home and lifestyle    498
# Name: Quantity, dtype: int64

# %%
# which is the most used mode of payment for sport and travel items in yangon*****
df_yangon=df2[(df2.City=='Yangon')]
df_yangon.head()
# Out:
#     Invoice_ID Branch    City Customer_Type  Gender            Product_Line  \
# 0  750-67-8428      A  Yangon        Member  Female       Health and beauty
# 2  631-41-3108      A  Yangon        Normal    Male      Home and lifestyle
# 3  123-19-1176      A  Yangon        Member    Male       Health and beauty
# 4  373-73-7910      A  Yangon        Normal    Male       Sports and travel
# 6  355-53-5943      A  Yangon        Member  Female  Electronic accessories
#
#    Unit_Price  Quantity   Tax 5%     Total       Date                Time  \
# 0       74.69         7  26.1415  548.9715 2019-01-05 2024-01-24 13:08:00
# 2       46.33         7  16.2155  340.5255 2019-03-03 2024-01-24 13:23:00
# 3       58.22         8  23.2880  489.0480 2019-01-27 2024-01-24 20:33:00
# 4       86.31         7  30.2085  634.3785 2019-02-08 2024-01-24 10:37:00
# 6       68.84         6  20.6520  433.6920 2019-02-25 2024-01-24 14:36:00
#
# ...

# %%
df_sport=df_yangon[(df_yangon.Product_Line=='Sports and travel')]
df_sport.head()
# Out:
#      Invoice_ID Branch    City Customer_Type Gender       Product_Line  \
# 4   373-73-7910      A  Yangon        Normal   Male  Sports and travel
# 17  765-26-6951      A  Yangon        Normal   Male  Sports and travel
# 24  549-59-1358      A  Yangon        Member   Male  Sports and travel
# 36  129-29-8530      A  Yangon        Member   Male  Sports and travel
# 63  199-75-8169      A  Yangon        Member   Male  Sports and travel
#
#     Unit_Price  Quantity   Tax 5%     Total       Date                Time  \
# 4        86.31         7  30.2085  634.3785 2019-02-08 2024-01-24 10:37:00
# 17       72.61         6  21.7830  457.4430 2019-01-01 2024-01-24 10:39:00
# 24       88.63         3  13.2945  279.1845 2019-03-02 2024-01-24 17:36:00
# 36       62.62         5  15.6550  328.7550 2019-03-10 2024-01-24 19:15:00
# 63       15.81        10   7.9050  166.0050 2019-03-06 2024-01-24 12:27:00
#
#         Payment    cogs  Gross_margin_Percentage  Gross_Income  Rating  day  \
# ...

# %%
paym=df_sport.groupby('Payment')['Quantity'].sum().sort_values(ascending=False)
payee=paym.reset_index()
payee
# Out:
#        Payment  Quantity
# 0      Ewallet       119
# 1         Cash       112
# 2  Credit card       102

# %%
payee['Payment'][0]
# Out:
# 'Ewallet'

# %%
# in yangon which mode of payment is most preferred and which sex prefers
# it most
df_yangon=df2[(df2.City=='Yangon')]
df_yangon.head()
# Out:
#     Invoice_ID Branch    City Customer_Type  Gender            Product_Line  \
# 0  750-67-8428      A  Yangon        Member  Female       Health and beauty
# 2  631-41-3108      A  Yangon        Normal    Male      Home and lifestyle
# 3  123-19-1176      A  Yangon        Member    Male       Health and beauty
# 4  373-73-7910      A  Yangon        Normal    Male       Sports and travel
# 6  355-53-5943      A  Yangon        Member  Female  Electronic accessories
#
#    Unit_Price  Quantity   Tax 5%     Total       Date                Time  \
# 0       74.69         7  26.1415  548.9715 2019-01-05 2024-01-24 13:08:00
# 2       46.33         7  16.2155  340.5255 2019-03-03 2024-01-24 13:23:00
# 3       58.22         8  23.2880  489.0480 2019-01-27 2024-01-24 20:33:00
# 4       86.31         7  30.2085  634.3785 2019-02-08 2024-01-24 10:37:00
# 6       68.84         6  20.6520  433.6920 2019-02-25 2024-01-24 14:36:00
#
# ...

# %%
df_yangon.groupby('Payment')['Quantity'].sum().sort_values(ascending=False)
# Out:
# Payment
# Ewallet        707
# Credit card    580
# Cash           572
# Name: Quantity, dtype: int64

# %%
df_yangon['Payment'].value_counts()
# Out:
# Ewallet        126
# Cash           110
# Credit card    104
# Name: Payment, dtype: int64

# %%
df_ewal=df_yangon[(df_yangon.Payment=='Ewallet')]
df_ewal.head()
# Out:
#      Invoice_ID Branch    City Customer_Type  Gender            Product_Line  \
# 0   750-67-8428      A  Yangon        Member  Female       Health and beauty
# 3   123-19-1176      A  Yangon        Member    Male       Health and beauty
# 4   373-73-7910      A  Yangon        Normal    Male       Sports and travel
# 6   355-53-5943      A  Yangon        Member  Female  Electronic accessories
# 12  365-64-0515      A  Yangon        Normal  Female  Electronic accessories
#
#     Unit_Price  Quantity   Tax 5%     Total       Date                Time  \
# 0        74.69         7  26.1415  548.9715 2019-01-05 2024-01-24 13:08:00
# 3        58.22         8  23.2880  489.0480 2019-01-27 2024-01-24 20:33:00
# 4        86.31         7  30.2085  634.3785 2019-02-08 2024-01-24 10:37:00
# 6        68.84         6  20.6520  433.6920 2019-02-25 2024-01-24 14:36:00
# 12       46.95         5  11.7375  246.4875 2019-02-12 2024-01-24 10:25:00
#
# ...

# %%
df_ewal_male=df_ewal[(df_ewal.Gender=='Male')]
df_ewal_male.head()
# Out:
#      Invoice_ID Branch    City Customer_Type Gender            Product_Line  \
# 3   123-19-1176      A  Yangon        Member   Male       Health and beauty
# 4   373-73-7910      A  Yangon        Normal   Male       Sports and travel
# 13  252-56-2699      A  Yangon        Normal   Male      Food and beverages
# 23  636-48-8204      A  Yangon        Normal   Male  Electronic accessories
# 24  549-59-1358      A  Yangon        Member   Male       Sports and travel
#
#     Unit_Price  Quantity   Tax 5%     Total       Date                Time  \
# 3        58.22         8  23.2880  489.0480 2019-01-27 2024-01-24 20:33:00
# 4        86.31         7  30.2085  634.3785 2019-02-08 2024-01-24 10:37:00
# 13       43.19        10  21.5950  453.4950 2019-02-07 2024-01-24 16:48:00
# 23       34.56         5   8.6400  181.4400 2019-02-17 2024-01-24 11:15:00
# 24       88.63         3  13.2945  279.1845 2019-03-02 2024-01-24 17:36:00
#
# ...

# %%
df2_ewal=df_ewal_male.groupby('Payment')['Quantity'].sum().sort_values(ascending=False)
df2_ewal
# Out:
# Payment
# Ewallet    375
# Name: Quantity, dtype: int64

# %%
df_ewal_female=df_ewal[(df_ewal.Gender=='Female')]
df_ewal_female.head()
# Out:
#      Invoice_ID Branch    City Customer_Type  Gender            Product_Line  \
# 0   750-67-8428      A  Yangon        Member  Female       Health and beauty
# 6   355-53-5943      A  Yangon        Member  Female  Electronic accessories
# 12  365-64-0515      A  Yangon        Normal  Female  Electronic accessories
# 37  272-65-1806      A  Yangon        Normal  Female  Electronic accessories
# 92  873-51-0671      A  Yangon        Member  Female       Sports and travel
#
#     Unit_Price  Quantity   Tax 5%     Total       Date                Time  \
# 0        74.69         7  26.1415  548.9715 2019-01-05 2024-01-24 13:08:00
# 6        68.84         6  20.6520  433.6920 2019-02-25 2024-01-24 14:36:00
# 12       46.95         5  11.7375  246.4875 2019-02-12 2024-01-24 10:25:00
# 37       60.88         9  27.3960  575.3160 2019-01-15 2024-01-24 17:17:00
# 92       21.98         7   7.6930  161.5530 2019-01-10 2024-01-24 16:42:00
#
# ...

# %%
df_ewal_female.groupby('Payment')['Quantity'].sum().sort_values(ascending=False)
# Out:
# Payment
# Ewallet    332
# Name: Quantity, dtype: int64

# %%
df2['month'].unique()
# Out:
# array([1, 3, 2], dtype=int64)

# %%
# in the city of mandalay, how much quantity of food and beverages were consumed
# between january to september/////
df_mandalay=df2[(df2.City=='Mandalay')]
df_mandalay.head()
# Out:
#      Invoice_ID Branch      City Customer_Type  Gender  \
# 9   692-92-5582      B  Mandalay        Member  Female
# 10  351-62-0822      B  Mandalay        Member  Female
# 11  529-56-3974      B  Mandalay        Member    Male
# 15  299-46-1805      B  Mandalay        Member  Female
# 19  319-50-3348      B  Mandalay        Normal  Female
#
#               Product_Line  Unit_Price  Quantity  Tax 5%    Total       Date  \
# 9       Food and beverages       54.84         3   8.226  172.746 2019-02-20
# 10     Fashion accessories       14.48         4   2.896   60.816 2019-02-06
# 11  Electronic accessories       25.51         4   5.102  107.142 2019-03-09
# 15       Sports and travel       93.72         6  28.116  590.436 2019-01-15
# 19      Home and lifestyle       40.30         2   4.030   84.630 2019-03-11
#
#                   Time      Payment    cogs  Gross_margin_Percentage  \
# 9  2024-01-24 13:27:00  Credit card  164.52                 4.761905
# ...

# %%
df_food_bev=df_mandalay[(df_mandalay.Product_Line=='Food and beverages')]
df_food_bev.head()
# Out:
#      Invoice_ID Branch      City Customer_Type  Gender        Product_Line  \
# 9   692-92-5582      B  Mandalay        Member  Female  Food and beverages
# 28  145-94-9061      B  Mandalay        Normal  Female  Food and beverages
# 47  727-46-3608      B  Mandalay        Member  Female  Food and beverages
# 72  510-95-6347      B  Mandalay        Member  Female  Food and beverages
# 81  847-38-7188      B  Mandalay        Normal  Female  Food and beverages
#
#     Unit_Price  Quantity   Tax 5%     Total       Date                Time  \
# 9        54.84         3   8.2260  172.7460 2019-02-20 2024-01-24 13:27:00
# 28       88.36         5  22.0900  463.8900 2019-01-25 2024-01-24 19:48:00
# 47       20.01         9   9.0045  189.0945 2019-02-06 2024-01-24 15:47:00
# 72       48.52         3   7.2780  152.8380 2019-03-05 2024-01-24 18:17:00
# 81       96.68         3  14.5020  304.5420 2019-01-26 2024-01-24 19:56:00
#
# ...

# %%
df_food_bev.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 9 to 979
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice_ID               50 non-null     object
#  1   Branch                   50 non-null     object
#  2   City                     50 non-null     object
#  3   Customer_Type            50 non-null     object
#  4   Gender                   50 non-null     object
#  5   Product_Line             50 non-null     object
#  6   Unit_Price               50 non-null     float64
#  7   Quantity                 50 non-null     int64
#  8   Tax 5%                   50 non-null     float64
#  9   Total                    50 non-null     float64
#  10  Date                     50 non-null     datetime64[ns]
#  11  Time                     50 non-null     datetime64[ns]
#  12  Payment                  50 non-null     object
# ...

# %%
df_food_bev.groupby('Product_Line')['Quantity'].sum()
# Out:
# Product_Line
# Food and beverages    270
# Name: Quantity, dtype: int64

# %%
df_jan_sept=df_food_bev[(df_food_bev.month==1)| (df_food_bev.month==2)|(df_food_bev.month==3)|(df_food_bev.month==4)|(df_food_bev.month==5)|(df_food_bev.month==6)|(df_food_bev.month==7)|(df_food_bev.month==8)|(df_food_bev.month==9)]
df_jan_sept.head()
# Out:
#      Invoice_ID Branch      City Customer_Type  Gender        Product_Line  \
# 9   692-92-5582      B  Mandalay        Member  Female  Food and beverages
# 28  145-94-9061      B  Mandalay        Normal  Female  Food and beverages
# 47  727-46-3608      B  Mandalay        Member  Female  Food and beverages
# 72  510-95-6347      B  Mandalay        Member  Female  Food and beverages
# 81  847-38-7188      B  Mandalay        Normal  Female  Food and beverages
#
#     Unit_Price  Quantity   Tax 5%     Total       Date                Time  \
# 9        54.84         3   8.2260  172.7460 2019-02-20 2024-01-24 13:27:00
# 28       88.36         5  22.0900  463.8900 2019-01-25 2024-01-24 19:48:00
# 47       20.01         9   9.0045  189.0945 2019-02-06 2024-01-24 15:47:00
# 72       48.52         3   7.2780  152.8380 2019-03-05 2024-01-24 18:17:00
# 81       96.68         3  14.5020  304.5420 2019-01-26 2024-01-24 19:56:00
#
# ...

# %%
df_jan_sept.groupby('Product_Line')['Quantity'].sum()
# Out:
# Product_Line
# Food and beverages    270
# Name: Quantity, dtype: int64

# %%
# in Naypyitaw how many normal customers were females
df_norm=df2[(df2.City=='Naypyitaw')]
df2_norm=df_norm[(df_norm.Gender=='Female')]
df3_no=df2_norm[(df2_norm.Customer_Type=='Normal')]

# %%
df3_norm=df3_no.value_counts().sum()
df3_norm
# Out:
# 82

# %%
# what percentage of member customers were males in yagon




compare the profit in percentage for each of the months in 2019

df_perc=df_yangon[(df_yangon.Customer_Type=='Member')]
df_perc
# Out:
#   Cell In[48], line 6
#     compare the profit in percentage for each of the months in 2019
#             ^
# SyntaxError: invalid syntax

# %%
percentage=df_perc['Customer_Type'].value_counts().sum()
percentage
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 percentage=df_perc['Customer_Type'].value_counts().sum()
#       2 percentage
#
# NameError: name 'df_perc' is not defined

# %%
percent=percentage.item()
percent

# %%
df_perc_male=df_perc[(df_perc.Gender=='Male')]
df_perc_male.head()

# %%
maleperc=df_perc_male['Gender'].value_counts().sum()
maleperc

# %%
ptotal=(maleperc/percent)*100
ptotal

# %%
# splitting
# df[['duration', 'time']]=df.duration.str.split(expand=True)

# %%
df[['Date','year']]=df.Date.str.split(expand=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 df[['Date','year']]=df.Date.str.split(expand=True)
#
# File ~\python\Lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# File ~\python\Lib\site-packages\pandas\core\accessor.py:182, in CachedAccessor.__get__(self, obj, cls)
#     179 if obj is None:
#     180     # we're accessing the attribute of the class, i.e., Dataset.geo
#     181     return self._accessor
# --> 182 accessor_obj = self._accessor(obj)
# ...

# %%
when do you use value counts and when do you sum by quantity or total
